# %%
import os
from IPython.display import Image

# %%
os.chdir("..")

# %%
image_path = "./examples"
gb_img_dog = "./examples/cam_gb_dog.jpg"
gradcam_img_dog = "./examples/cam_dog.jpg"
os.listdir(image_path)
# Out:
# ['cam_dog.jpg',
#  '.DS_Store',
#  'cam_gb_dog.jpg',
#  'person1.jpg',
#  'gb.jpg',
#  'cam.jpg',
#  'cam_gb.jpg',
#  'gb_dog.jpg',
#  'cam_person.jpg',
#  'cam_gb_person.jpg',
#  'gb_person.jpg']

# %%
Image(gradcam_img_dog)

# %%
Image(gb_img_dog)

# %% [markdown]
# The above two images are generated from the Grad-CAM algorithm and the guided backpropogation algorithm. Grad-CAM algorithm visualizes a model by producing a heatmap onto the part of the image which the model thinks is the most important feature. Backpropogation algorithm have neurons acting like detectors of features. The more important the model thinks a particular feature is, the more obvious it will be on the image. Here the model successfully recognizes the dog in the image.

# %%
gb_img_person = "./examples/gb_person.jpg"
gradcam_img_person = "./examples/cam_person.jpg"

# %%
Image(gradcam_img_person)

# %%
Image(gb_img_person)

# %% [markdown]
# The above two images of three women are also generated from Grad-CAM and backpropogation algorithm. Our model successfully recognizes the women in the picture and we can see a heatmap is produced onto them. And we can see from the one generated from the backpropogation algorithm, the women are visible in the image. Note that the model not only successfully recognizes one person but all three people in the image.
